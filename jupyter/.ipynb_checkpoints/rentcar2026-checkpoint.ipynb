# %%
# import zone
import pandas as pd

df02 = pd.read_csv('charangData/user.csv',encoding='cp949')
df07_booking = pd.read_csv('charangData/booking.csv',encoding='cp949')
df07_car = pd.read_csv('charangData/car.csv',encoding='cp949')

# %% [markdown]
# ### 2. **월별 가입자수 추이**
# #### - **그래프유형**: 꺾은선 그래프
# #### - **기대효과**: 월별 가입차 추이를 통해 유입이 저조한 달의 경우, 대책 기획
# #### - **X축**: 월(Month)
# #### - **Y축**: 가입자수(Count)
# #### - **Raw Data**: user

# %%
# 셀은 하나만 쓴다.
print(df02.isna().sum())
# Out:
# userId           0
# userPw           0
# name             0
# mail             0
# resistNum        0
# phone            0
# address          0
# addressDetail    0
# isKorean         0
# license          0
# licenseNum       0
# regDate          0
# modDate          0
# dtype: int64

# %% [markdown]
# ### .7 **차종별(연료타입분리x) 예약 횟수**
# #### - **그래프유형**: 막대사탕 차트
# #### - **기대효과**: 인기 차량 확인가능. 들여올 차량 선정시 유효
# #### - **X축**: 수(Count)
# #### - **Raw Data**: booking / car

# %%
merge07 = pd.merge(df07_booking,df07_car,how='outer',on='carId')
# print(merge07.isna().sum())
result = pd.DataFrame({
    "모델":[merge07.groupby('model')],
    "예약건수":[merge07.groupby('model').count()]
}
# merge07.groupby('model').count()
# merge07['예약건수'] = 1
print(result)
# merge07.groupby('model').size()
# Out:
# bookingId         67
# userId            67
# carId              0
# bookedDate        67
# startDate         67
# startTime         67
# endDate           67
# endTime           67
# carPrice          67
# insurancePrice    67
# totalPrice        67
# paymentMethod     67
# carImg             0
# brandLogo          0
# brand              0
# model              0
# color              0
# plateNumber        0
# modelYear          0
# seats              0
# carSize            0
# carType            0
# fuelType           0
# modDate            0
# regDate            0
# branchId           0
# licenseType        0
# driverMinAge       0
# kmPer              0
# priceValue         0
# navigation         0
# rearCamera         0
# heatSeat           0
# heatHandle         0
# bluetooth          0
# smartKey           0
# sunRoof            0
# dtype: int64
#                   bookingId      userId  carId  bookedDate   startDate  \
# ...
