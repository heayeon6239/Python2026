# %%
# 01. 반드시 pandas는 import하여 사용
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용
import matplotlib.pyplot as plt

# 02. 데이터 생성하기
df1 = pd.DataFrame({
    "지역": ["서울", "부산", "대구"],
    "총인구": [1000000,300000, 200000]
})

df2 = pd.DataFrame({
    "지역": ["서울", "부산", "인천"],
    "병원수": [150,80, 60]
})

# 03. 데이터 전처리를 위해 merge(병합)
# outer로 병합하면 df1과 df2의 합집합
merged = pd.merge(df1, df2, on="지역", how="outer")
merged
# 04. 결측치 처리
merged["총인구"] = merged["총인구"].fillna(merged["총인구"].mean())
merged["병원수"] = merged["병원수"].fillna(merged["병원수"].mean())

# -----------------------------

# 01. 한글 깨짐 방지 설정★
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(6,6))

# 원형 그래프 : plt.pie(항목)
# labels = merged['지역'] => 원형 그래프 각 조각의 이름
# autopct = '%1.1f%%' => 원형 그래프 각 조각의 백분율 출력
# startangle = 90 => 원형 그래프 시작 위치, 90이면 위쪽부터 시작
plt.pie(merged['병원수'],labels=merged['지역'], autopct='%1.1f%%',startangle=90)

plt.title('지역별 병원수 비율')
plt.show()

# %%
# 01. 반드시 pandas는 import하여 사용
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용
import matplotlib.pyplot as plt

# 02. 데이터 생성하기
df1 = pd.DataFrame({
    "지역": ["서울", "부산", "대구"],
    "총인구": [1000000,300000, 200000]
})

df2 = pd.DataFrame({
    "지역": ["서울", "부산", "인천"],
    "병원수": [150,80, 60]
})

# 03. 데이터 전처리를 위해 merge(병합)
# outer로 병합하면 df1과 df2의 합집합
merged = pd.merge(df1, df2, on="지역", how="outer")
merged
# 04. 결측치 처리
merged["총인구"] = merged["총인구"].fillna(merged["총인구"].mean())
merged["병원수"] = merged["병원수"].fillna(merged["병원수"].mean())

# -----------------------------

# 01. 한글 깨짐 방지 설정★

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(6,6))

plt.pie(merged['병원수'],labels=merged['지역'], autopct='%1.1f%%',startangle=90)

# 도넛 그래프 : plt.pie(항목)

# plt.Circle((0,0),0.6 fc='white')
# (0,0) => 중심, 반지름 0.6짜리ㅡ 흰색원을 그림
centre_circle = plt.Circle((0,0),0.6, fc='white')
# plt.gca().add_artist(center_circle) => 그래프에 추가해줘
plt.gca().add_artist(centre_circle)

plt.title('지역별 병원수 비율(도넛형)')
plt.show()

# %%
# 01. 반드시 pandas는 import하여 사용
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용
import matplotlib.pyplot as plt
import seaborn as sns

# 02. 데이터 생성하기
df1 = pd.DataFrame({
    "지역": ["서울", "부산", "대구"],
    "총인구": [1000000,300000, 200000]
})

df2 = pd.DataFrame({
    "지역": ["서울", "부산", "인천"],
    "병원수": [150,80, 60]
})

# 03. 데이터 전처리를 위해 merge(병합)
# outer로 병합하면 df1과 df2의 합집합
merged = pd.merge(df1, df2, on="지역", how="outer")
merged
# 04. 결측치 처리
merged["총인구"] = merged["총인구"].fillna(merged["총인구"].mean())
merged["병원수"] = merged["병원수"].fillna(merged["병원수"].mean())

# -----------------------------
# 스타일
sns.set_style('whitegrid') # 배경 스타일 설정, dark : 그리드 없이 어두운 배경 지정
sns.set_palette('pastel') # 색상 스타일 지정, deep : 진하게

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

# 01. 한글 깨짐 방지 설정★
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(6,6))

# ★각 조각을 돌출할 때 사용하는 명령어
# explode 설정 => explode = [0.05] * len(merged)
# [0.05],[0.05],[0.05],[0.05]만큼 사이가 벌어짐
explode = [0.03] * len(merged)

# ★원형 그래프 : plt.pie(항목)
# labels = merged['지역'] => 원형 그래프 각 조각의 이름
# autopct = '%1.1f%%' => 원형 그래프 각 조각의 백분율 출력
# startangle = 90 => 원형 그래프 시작 위치, 90이면 위쪽부터 시작

plt.pie(merged['병원수'], # 데이터 값(각 조각의 크기)
        labels=merged['지역'], # 각 조각의 이름
        autopct='%1.1f%%', # 퍼센트 표시(소수점 1자리)
        startangle=90, # 시작 위치(위쪽부터 시작)
        colors= colors, # 각 조각 색상 지정
        explode = explode, # 각 조각을 바깥쪽으로 얼마나 띄울지 지정
        wedgeprops={'edgecolor':'white'}, # 각 조각 사이의 흰색 경계선 출력
        textprops={'fontsize':12, 'color':'black'}
       )

plt.title('지역별 병원수 비율')
plt.show()

# %%
# 01. 반드시 pandas는 import하여 사용
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용
import matplotlib.pyplot as plt
import seaborn as sns

# 02. 데이터 생성하기
df1 = pd.DataFrame({
    "지역": ["서울", "부산", "대구"],
    "총인구": [1000000,300000, 200000]
})

df2 = pd.DataFrame({
    "지역": ["서울", "부산", "인천"],
    "병원수": [150,80, 60]
})

# 03. 데이터 전처리를 위해 merge(병합)
# outer로 병합하면 df1과 df2의 합집합
merged = pd.merge(df1, df2, on="지역", how="outer")
merged
# 04. 결측치 처리
merged["총인구"] = merged["총인구"].fillna(merged["총인구"].mean())
merged["병원수"] = merged["병원수"].fillna(merged["병원수"].mean())

# -----------------------------
# 스타일
sns.set_style('whitegrid') # 배경 스타일 설정, dark : 그리드 없이 어두운 배경 지정
sns.set_palette('pastel') # 색상 스타일 지정, deep : 진하게

# 01. 한글 깨짐 방지 설정★

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(6,6))

explode = [0.03] * len(merged)

plt.pie(
    merged['병원수'],
    labels=merged['지역'], 
    autopct='%1.1f%%',
    startangle=90,
    wedgeprops={'edgecolor':'white'},
    explode = explode,
    pctdistance = 0.75 # 퍼센트를 도넛 안쪽으로 이동
       )

# 도넛 그래프 : plt.pie(항목)

# plt.Circle((0,0),0.6 fc='white')
# (0,0) => 중심, 반지름 0.6짜리ㅡ 흰색원을 그림
centre_circle = plt.Circle((0,0),0.6, fc='white')
# plt.gca().add_artist(center_circle) => 그래프에 추가해줘
plt.gca().add_artist(centre_circle)

plt.title('지역별 병원수 비율(도넛형)')
plt.show()
